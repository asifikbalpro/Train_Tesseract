# %%
# !mkdir fonts output train
# Out:
# mkdir: cannot create directory ‘fonts’: File exists
# mkdir: cannot create directory ‘output’: File exists
# mkdir: cannot create directory ‘train’: File exists

# %%
font_name = 'Arial Th'

# %%
# !chmod 755 -R tesseract/src/training/tesstrain.sh

# %%
# !combine_tessdata -e tesseract/tessdata/eng.traineddata eng.lstm
# Out:
# Extracting tessdata components from tesseract/tessdata/eng.traineddata
# Wrote eng.lstm
# Version string:4.00.00alpha:eng:synth20170629:[1,36,0,1Ct3,3,16Mp3,3Lfys64Lfx96Lrx96Lfx512O1c1]
# 17:lstm:size=11689099, offset=192
# 18:lstm-punc-dawg:size=4322, offset=11689291
# 19:lstm-word-dawg:size=3694794, offset=11693613
# 20:lstm-number-dawg:size=4738, offset=15388407
# 21:lstm-unicharset:size=6360, offset=15393145
# 22:lstm-recoder:size=1012, offset=15399505
# 23:version:size=80, offset=15400517

# %%
# !rm -rf train/*
# !tesseract/src/training/tesstrain.sh --fonts_dir fonts \
--fontlist '{font_name}' \
--lang eng \
--linedata_only \
--langdata_dir langdata_lstm \
--tessdata_dir tesseract/tessdata \
--save_box_tiff \
--maxpages 10 \
--output_dir train
# Out:
# === Starting training for language 'eng'
# [Tue Aug 9 04:20:45 PM +06 2022] /usr/bin/text2image --fonts_dir=fonts --ptsize 12 --font=Arial Th --outputbase=/tmp/font_tmp.7hkJrramY3/sample_text.txt --text=/tmp/font_tmp.7hkJrramY3/sample_text.txt --fontconfig_tmpdir=/tmp/font_tmp.7hkJrramY3
# Rendered page 0 to file /tmp/font_tmp.7hkJrramY3/sample_text.txt.tif
#
# === Phase I: Generating training images ===
# Rendering using Arial Th
# [Tue Aug 9 04:20:46 PM +06 2022] /usr/bin/text2image --fontconfig_tmpdir=/tmp/font_tmp.7hkJrramY3 --fonts_dir=fonts --strip_unrenderable_words --leading=32 --xsize=3600 --char_spacing=0.0 --exposure=0 --outputbase=/tmp/eng-2022-08-09.CMY/eng.Arial_Th.exp0 --max_pages=10 --font=Arial Th --ptsize 12 --text=langdata_lstm/eng/eng.training_text
# Stripped 3 unrenderable words
# Rendered page 0 to file /tmp/eng-2022-08-09.CMY/eng.Arial_Th.exp0.tif
# Stripped 8 unrenderable words
# Rendered page 1 to file /tmp/eng-2022-08-09.CMY/eng.Arial_Th.exp0.tif
# Stripped 11 unrenderable words
# Rendered page 2 to file /tmp/eng-2022-08-09.CMY/eng.Arial_Th.exp0.tif
# Stripped 8 unrenderable words
# Rendered page 3 to file /tmp/eng-2022-08-09.CMY/eng.Arial_Th.exp0.tif
# Stripped 8 unrenderable words
# Rendered page 4 to file /tmp/eng-2022-08-09.CMY/eng.Arial_Th.exp0.tif
# Stripped 12 unrenderable words
# Rendered page 5 to file /tmp/eng-2022-08-09.CMY/eng.Arial_Th.exp0.tif
# Stripped 3 unrenderable words
# Rendered page 6 to file /tmp/eng-2022-08-09.CMY/eng.Arial_Th.exp0.tif
# Stripped 7 unrenderable words
# Rendered page 7 to file /tmp/eng-2022-08-09.CMY/eng.Arial_Th.exp0.tif
# Stripped 6 unrenderable words
# Rendered page 8 to file /tmp/eng-2022-08-09.CMY/eng.Arial_Th.exp0.tif
# Stripped 7 unrenderable words
# Rendered page 9 to file /tmp/eng-2022-08-09.CMY/eng.Arial_Th.exp0.tif
#
# === Phase UP: Generating unicharset and unichar properties files ===
# [Tue Aug 9 04:20:50 PM +06 2022] /usr/bin/unicharset_extractor --output_unicharset /tmp/eng-2022-08-09.CMY/eng.unicharset --norm_mode 1 /tmp/eng-2022-08-09.CMY/eng.Arial_Th.exp0.box
# Extracting unicharset from box file /tmp/eng-2022-08-09.CMY/eng.Arial_Th.exp0.box
# Other case É of é is not in unicharset
# Wrote unicharset file /tmp/eng-2022-08-09.CMY/eng.unicharset
# [Tue Aug 9 04:20:50 PM +06 2022] /usr/bin/set_unicharset_properties -U /tmp/eng-2022-08-09.CMY/eng.unicharset -O /tmp/eng-2022-08-09.CMY/eng.unicharset -X /tmp/eng-2022-08-09.CMY/eng.xheights --script_dir=langdata_lstm
# Loaded unicharset of size 111 from file /tmp/eng-2022-08-09.CMY/eng.unicharset
# Setting unichar properties
# Other case É of é is not in unicharset
# Setting script properties
# Failed to load script unicharset from:langdata_lstm/Latin.unicharset
# Warning: properties incomplete for index 3 = P
# Warning: properties incomplete for index 4 = U
# Warning: properties incomplete for index 5 = R
# Warning: properties incomplete for index 6 = I
# Warning: properties incomplete for index 7 = T
# Warning: properties incomplete for index 8 = Y
# Warning: properties incomplete for index 9 = §
# Warning: properties incomplete for index 10 = “
# Warning: properties incomplete for index 11 = e
# Warning: properties incomplete for index 12 = d
# Warning: properties incomplete for index 13 = u
# Warning: properties incomplete for index 14 = c
# Warning: properties incomplete for index 15 = a
# Warning: properties incomplete for index 16 = t
# Warning: properties incomplete for index 17 = i
# Warning: properties incomplete for index 18 = o
# Warning: properties incomplete for index 19 = n
# Warning: properties incomplete for index 20 = l
# Warning: properties incomplete for index 21 = |
# Warning: properties incomplete for index 22 = f
# Warning: properties incomplete for index 23 = r
# Warning: properties incomplete for index 24 = h
# Warning: properties incomplete for index 25 = x
# Warning: properties incomplete for index 26 = v
# Warning: properties incomplete for index 27 = s
# Warning: properties incomplete for index 28 = ;
# Warning: properties incomplete for index 29 = O
# Warning: properties incomplete for index 30 = F
# Warning: properties incomplete for index 31 = E
# Warning: properties incomplete for index 32 = S
# Warning: properties incomplete for index 33 = N
# Warning: properties incomplete for index 34 = A
# Warning: properties incomplete for index 35 = L
# Warning: properties incomplete for index 36 = p
# Warning: properties incomplete for index 37 = b
# Warning: properties incomplete for index 38 = y
# Warning: properties incomplete for index 39 = C
# Warning: properties incomplete for index 40 = W
# Warning: properties incomplete for index 41 = m
# Warning: properties incomplete for index 42 = M
# Warning: properties incomplete for index 43 = k
# Warning: properties incomplete for index 44 = B
# Warning: properties incomplete for index 45 = @
# Warning: properties incomplete for index 46 = D
# Warning: properties incomplete for index 47 = G
# Warning: properties incomplete for index 48 = ®
# Warning: properties incomplete for index 49 = g
# Warning: properties incomplete for index 50 = >
# Warning: properties incomplete for index 51 = w
# Warning: properties incomplete for index 52 = H
# Warning: properties incomplete for index 53 = V
# Warning: properties incomplete for index 54 = °
# Warning: properties incomplete for index 55 = «
# Warning: properties incomplete for index 56 = )
# Warning: properties incomplete for index 57 = :
# Warning: properties incomplete for index 58 = .
# Warning: properties incomplete for index 59 = ,
# Warning: properties incomplete for index 60 = /
# Warning: properties incomplete for index 61 = 7
# Warning: properties incomplete for index 62 = 0
# Warning: properties incomplete for index 63 = (
# Warning: properties incomplete for index 64 = [
# Warning: properties incomplete for index 65 = X
# Warning: properties incomplete for index 66 = 2
# Warning: properties incomplete for index 67 = 3
# Warning: properties incomplete for index 68 = }
# Warning: properties incomplete for index 69 = ¥
# Warning: properties incomplete for index 70 = {
# Warning: properties incomplete for index 71 = ”
# Warning: properties incomplete for index 72 = !
# Warning: properties incomplete for index 73 = K
# Warning: properties incomplete for index 74 = j
# Warning: properties incomplete for index 75 = ™
# Warning: properties incomplete for index 76 = »
# Warning: properties incomplete for index 77 = z
# Warning: properties incomplete for index 78 = ~
# Warning: properties incomplete for index 79 = <
# Warning: properties incomplete for index 80 = *
# Warning: properties incomplete for index 81 = +
# Warning: properties incomplete for index 82 = 5
# Warning: properties incomplete for index 83 = Z
# Warning: properties incomplete for index 84 = Q
# Warning: properties incomplete for index 85 = J
# Warning: properties incomplete for index 86 = $
# Warning: properties incomplete for index 87 = q
# Warning: properties incomplete for index 88 = £
# Warning: properties incomplete for index 89 = 1
# Warning: properties incomplete for index 90 = 9
# Warning: properties incomplete for index 91 = '
# Warning: properties incomplete for index 92 = %
# Warning: properties incomplete for index 93 = &
# Warning: properties incomplete for index 94 = 4
# Warning: properties incomplete for index 95 = ¢
# Warning: properties incomplete for index 96 = 6
# Warning: properties incomplete for index 97 = —
# Warning: properties incomplete for index 98 = ’
# Warning: properties incomplete for index 99 = ?
# Warning: properties incomplete for index 100 = ]
# Warning: properties incomplete for index 101 = ‘
# Warning: properties incomplete for index 102 = -
# Warning: properties incomplete for index 103 = =
# Warning: properties incomplete for index 104 = "
# Warning: properties incomplete for index 105 = 8
# Warning: properties incomplete for index 106 = \
# Warning: properties incomplete for index 107 = _
# Warning: properties incomplete for index 108 = é
# Warning: properties incomplete for index 109 = ©
# Warning: properties incomplete for index 110 = #
# Writing unicharset to file /tmp/eng-2022-08-09.CMY/eng.unicharset
#
# === Phase E: Generating lstmf files ===
# Using TESSDATA_PREFIX=tesseract/tessdata
# [Tue Aug 9 04:20:50 PM +06 2022] /usr/bin/tesseract /tmp/eng-2022-08-09.CMY/eng.Arial_Th.exp0.tif /tmp/eng-2022-08-09.CMY/eng.Arial_Th.exp0 --psm 6 lstm.train
# Tesseract Open Source OCR Engine v4.1.1 with Leptonica
# Page 1
# Page 2
# Loaded 57/57 lines (1-57) of document /tmp/eng-2022-08-09.CMY/eng.Arial_Th.exp0.lstmf
# Page 3
# Loaded 114/114 lines (1-114) of document /tmp/eng-2022-08-09.CMY/eng.Arial_Th.exp0.lstmf
# Page 4
# Loaded 171/171 lines (1-171) of document /tmp/eng-2022-08-09.CMY/eng.Arial_Th.exp0.lstmf
# Page 5
# Loaded 228/228 lines (1-228) of document /tmp/eng-2022-08-09.CMY/eng.Arial_Th.exp0.lstmf
# Page 6
# Loaded 285/285 lines (1-285) of document /tmp/eng-2022-08-09.CMY/eng.Arial_Th.exp0.lstmf
# Page 7
# Loaded 342/342 lines (1-342) of document /tmp/eng-2022-08-09.CMY/eng.Arial_Th.exp0.lstmf
# Page 8
# Loaded 399/399 lines (1-399) of document /tmp/eng-2022-08-09.CMY/eng.Arial_Th.exp0.lstmf
# Page 9
# Loaded 456/456 lines (1-456) of document /tmp/eng-2022-08-09.CMY/eng.Arial_Th.exp0.lstmf
# Page 10
# Loaded 513/513 lines (1-513) of document /tmp/eng-2022-08-09.CMY/eng.Arial_Th.exp0.lstmf
#
# === Constructing LSTM training data ===
# [Tue Aug 9 04:20:53 PM +06 2022] /usr/bin/combine_lang_model --input_unicharset /tmp/eng-2022-08-09.CMY/eng.unicharset --script_dir langdata_lstm --words langdata_lstm/eng/eng.wordlist --numbers langdata_lstm/eng/eng.numbers --puncs langdata_lstm/eng/eng.punc --output_dir train --lang eng
# Loaded unicharset of size 111 from file /tmp/eng-2022-08-09.CMY/eng.unicharset
# Setting unichar properties
# Other case É of é is not in unicharset
# Setting script properties
# Failed to load script unicharset from:langdata_lstm/Latin.unicharset
# Warning: properties incomplete for index 3 = P
# Warning: properties incomplete for index 4 = U
# Warning: properties incomplete for index 5 = R
# Warning: properties incomplete for index 6 = I
# Warning: properties incomplete for index 7 = T
# Warning: properties incomplete for index 8 = Y
# Warning: properties incomplete for index 9 = §
# Warning: properties incomplete for index 10 = “
# Warning: properties incomplete for index 11 = e
# Warning: properties incomplete for index 12 = d
# Warning: properties incomplete for index 13 = u
# Warning: properties incomplete for index 14 = c
# Warning: properties incomplete for index 15 = a
# Warning: properties incomplete for index 16 = t
# Warning: properties incomplete for index 17 = i
# Warning: properties incomplete for index 18 = o
# Warning: properties incomplete for index 19 = n
# Warning: properties incomplete for index 20 = l
# Warning: properties incomplete for index 21 = |
# Warning: properties incomplete for index 22 = f
# Warning: properties incomplete for index 23 = r
# Warning: properties incomplete for index 24 = h
# Warning: properties incomplete for index 25 = x
# Warning: properties incomplete for index 26 = v
# Warning: properties incomplete for index 27 = s
# Warning: properties incomplete for index 28 = ;
# Warning: properties incomplete for index 29 = O
# Warning: properties incomplete for index 30 = F
# Warning: properties incomplete for index 31 = E
# Warning: properties incomplete for index 32 = S
# Warning: properties incomplete for index 33 = N
# Warning: properties incomplete for index 34 = A
# Warning: properties incomplete for index 35 = L
# Warning: properties incomplete for index 36 = p
# Warning: properties incomplete for index 37 = b
# Warning: properties incomplete for index 38 = y
# Warning: properties incomplete for index 39 = C
# Warning: properties incomplete for index 40 = W
# Warning: properties incomplete for index 41 = m
# Warning: properties incomplete for index 42 = M
# Warning: properties incomplete for index 43 = k
# Warning: properties incomplete for index 44 = B
# Warning: properties incomplete for index 45 = @
# Warning: properties incomplete for index 46 = D
# Warning: properties incomplete for index 47 = G
# Warning: properties incomplete for index 48 = ®
# Warning: properties incomplete for index 49 = g
# Warning: properties incomplete for index 50 = >
# Warning: properties incomplete for index 51 = w
# Warning: properties incomplete for index 52 = H
# Warning: properties incomplete for index 53 = V
# Warning: properties incomplete for index 54 = °
# Warning: properties incomplete for index 55 = «
# Warning: properties incomplete for index 56 = )
# Warning: properties incomplete for index 57 = :
# Warning: properties incomplete for index 58 = .
# Warning: properties incomplete for index 59 = ,
# Warning: properties incomplete for index 60 = /
# Warning: properties incomplete for index 61 = 7
# Warning: properties incomplete for index 62 = 0
# Warning: properties incomplete for index 63 = (
# Warning: properties incomplete for index 64 = [
# Warning: properties incomplete for index 65 = X
# Warning: properties incomplete for index 66 = 2
# Warning: properties incomplete for index 67 = 3
# Warning: properties incomplete for index 68 = }
# Warning: properties incomplete for index 69 = ¥
# Warning: properties incomplete for index 70 = {
# Warning: properties incomplete for index 71 = ”
# Warning: properties incomplete for index 72 = !
# Warning: properties incomplete for index 73 = K
# Warning: properties incomplete for index 74 = j
# Warning: properties incomplete for index 75 = ™
# Warning: properties incomplete for index 76 = »
# Warning: properties incomplete for index 77 = z
# Warning: properties incomplete for index 78 = ~
# Warning: properties incomplete for index 79 = <
# Warning: properties incomplete for index 80 = *
# Warning: properties incomplete for index 81 = +
# Warning: properties incomplete for index 82 = 5
# Warning: properties incomplete for index 83 = Z
# Warning: properties incomplete for index 84 = Q
# Warning: properties incomplete for index 85 = J
# Warning: properties incomplete for index 86 = $
# Warning: properties incomplete for index 87 = q
# Warning: properties incomplete for index 88 = £
# Warning: properties incomplete for index 89 = 1
# Warning: properties incomplete for index 90 = 9
# Warning: properties incomplete for index 91 = '
# Warning: properties incomplete for index 92 = %
# Warning: properties incomplete for index 93 = &
# Warning: properties incomplete for index 94 = 4
# Warning: properties incomplete for index 95 = ¢
# Warning: properties incomplete for index 96 = 6
# Warning: properties incomplete for index 97 = —
# Warning: properties incomplete for index 98 = ’
# Warning: properties incomplete for index 99 = ?
# Warning: properties incomplete for index 100 = ]
# Warning: properties incomplete for index 101 = ‘
# Warning: properties incomplete for index 102 = -
# Warning: properties incomplete for index 103 = =
# Warning: properties incomplete for index 104 = "
# Warning: properties incomplete for index 105 = 8
# Warning: properties incomplete for index 106 = \
# Warning: properties incomplete for index 107 = _
# Warning: properties incomplete for index 108 = é
# Warning: properties incomplete for index 109 = ©
# Warning: properties incomplete for index 110 = #
# Config file is optional, continuing...
# Failed to read data from: langdata_lstm/eng/eng.config
# Null char=2
# Reducing Trie to SquishedDawg
# Reducing Trie to SquishedDawg
# Reducing Trie to SquishedDawg
#
# === Saving box/tiff pairs for training data ===
# Moving /tmp/eng-2022-08-09.CMY/eng.Arial_Th.exp0.box to train
# Moving /tmp/eng-2022-08-09.CMY/eng.Arial_Th.exp0.tif to train
#
# === Moving lstmf files for training data ===
# Moving /tmp/eng-2022-08-09.CMY/eng.Arial_Th.exp0.lstmf to train
#
# Created starter traineddata for LSTM training of language 'eng'
#
#
# Run 'lstmtraining' command to continue LSTM training for language 'eng'

# %%
# !rm -rf output/* 
# !OMP_THREAD_LIMIT=16 lstmtraining \
--continue_from eng.lstm \
--model_output output/font_name \
--traineddata tesseract/tessdata/eng.traineddata \
--train_listfile train/eng.training_files.txt \
--max_iterations 200
# Out:
# Loaded file eng.lstm, unpacking...
# Warning: LSTMTrainer deserialized an LSTMRecognizer!
# Continuing from eng.lstm
# Loaded 570/570 lines (1-570) of document train/eng.Arial_Th.exp0.lstmf
# 2 Percent improvement time=17, best error was 100 @ 0
# At iteration 17/100/100, Mean rms=0.323%, delta=0.136%, char train=0.458%, word train=1.353%, skip ratio=0%,  New best char error = 0.458 Transitioned to stage 1 wrote best model:output/font_name0.458_17.checkpoint wrote checkpoint.
#
# At iteration 32/200/200, Mean rms=0.328%, delta=0.16%, char train=0.503%, word train=1.299%, skip ratio=0%,  New worst char error = 0.503 wrote checkpoint.
#
# Finished! Error rate = 0.458

# %%
# !lstmtraining --stop_training \
--continue_from output/font_name_checkpoint \
--traineddata tesseract/tessdata/eng.traineddata \
--model_output output/font_name.traineddata
# Out:
# Loaded file output/font_name_checkpoint, unpacking...
